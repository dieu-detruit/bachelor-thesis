# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x, profile = np.loadtxt('../../data/diffraction_comparison/fwhm_approximation/sommerfeld_focus_profile2.txt').transpose()

profile_max = np.max(profile)
left_x = x[np.argmin(abs(profile - 0.5 * profile_max))]
fwhm = abs(left_x) * 2
print(fwhm)
# Out:
# 1.5e-05

# %%
profile /= profile_max
fig = plt.figure(figsize=(10, 8))
plt.xlim([-0.0001, 0.0001])
plt.plot(x, profile)
plt.plot(x, 0.5 * np.ones(x.shape))

fig.savefig('../../thesis/chap2/figure/fwhm_approximation.png')

# %%
# Out:
# -1e-05
