# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from matplotlib import rcParams

rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Hiragino Maru Gothic Pro', 'Yu Gothic', 'Meirio', 'Takao', 'IPAexGothic', 'IPAPGothic', 'VL PGothic', 'Noto Sans CJK JP']

# %%
x = np.linspace(-1, 1, 1000)
profile = np.exp(-x**2/0.5**2)

fig = plt.figure(figsize=(8, 4))
plt.plot(x, profile)
fig.savefig('../resource/chap2/gaussian_profile.png')

# %%
x = np.linspace(-1, 1, 1000)
profile = np.exp(-x**2/0.5**2)

fig = plt.figure(figsize=(8, 4))
#plt.plot(x, profile, x, label='ideal', 0.6 * profile, label='unideal')
plt.plot(x, profile, label='理想形状')
plt.plot(x, 0.6 * profile, label='非理想形状')
plt.legend(bbox_to_anchor=(1, 1), loc='upper right', borderaxespad=0, fontsize=18)
fig.savefig('../../thesis/chap2/figure/strehl.png')

# %%
x = np.linspace(-1, 1, 1000)
y = x.copy()
x, y = np.meshgrid(x, y)

focus = np.exp(-(x**2 + y**2)/0.5**2)

fig = plt.figure(figsize=(5, 5))
plt.imshow(focus)
fig.savefig('images/resource/gaussian_image.png')

# %%
focus_sum = np.sum(focus)
half_power = 1/2 * focus_sum
half_power
# Out:
# 97072.07634452151

# %%
sigma_px = 1000 * 0.5 / 2.0
K = int(0.74 * sigma_px)
print(K)
print(np.sum(focus[(500-K):(500+K), (500-K):(500+K)]))
print(2 * K)
# Out:
# 185
# 97440.27173422219
# 370

# %%
r = np.hypot(x, y)
focus[(0.73 * 0.5 <= r) & (r <= 0.74 * 0.5)] = 0

plt.figure(figsize=(5, 5))
plt.imshow(focus)
