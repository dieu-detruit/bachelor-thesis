# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
import matplotlib.font_manager as font_manager

N = 100
x = np.linspace(0.0, 1.0, N)

#y = 4 * x + np.sin(x) - 2 * np.sin(2 * x) - 4 * np.sin(10 * x)
y = 10 * x + 20 * x**2

z = np.angle(np.exp(1.0j * y))

fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111)

ax.plot(x, y, color='red', label="original function $f(x)$")
ax.plot(x, z, color='blue', label="$\mathrm{arg}\{\exp(if(x))\}$")
ax.plot(x, np.pi * np.ones(N), color='gray', label='$\pi$')
ax.plot(x, -np.pi * np.ones(N), color='gray', label='-$\pi$')

#ax.set_xticklabels(labels=ax.get_xticklabels(), fontsize=20)
#ax.set_yticklabels(labels=ax.get_yticklabels(), fontsize=20)
ax.tick_params(labelsize=20)
ax.legend(fontsize=18)
plt.show()

fig.savefig('../../thesis/chap3/figure/before_unwrap.png')

# %%
prev = z[0]
w = z.copy()
for i in range(N):
    if z[i] < prev - math.pi:
        z[i] += 2.0 * math.pi
    elif z[i] > prev + math.pi:
        z[i] -= 2.0 * math.pi
    prev = z[i]

# %%
plt.plot(x, z)
