# %%
import numpy as np
import matplotlib.pyplot as plt
import PIL.Image as Image
import math

# %%
def fraunhofer(src, z):
    if z > 0:
        return np.fft.fftshift(np.fft.fft2(np.fft.fftshift(src)))
    else:
        return np.fft.ifftshift(np.fft.ifft2(np.fft.ifftshift(src)))

# %%
def angular(src, dx, wavelength, z):

    ysize, xsize = src.shape
    
    src_expanded = np.zeros((2 * xsize, 2 * ysize), dtype=np.complex)
    src_expanded[(xsize//2):(3*xsize//2), (ysize//2):(3*ysize//2)] = src

    #showImg(np.abs(src_expanded))

    u = np.fft.fftfreq(2 * xsize, dx / 2)
    v = np.fft.fftfreq(2 * ysize, dx / 2)
    u, v = np.meshgrid(u, v)
  
    # antialias filter
    du = 1.0 / (dx * xsize)
    dv = 1.0 / (dx * ysize)
    u_limit = 1.0 / math.sqrt(1 + (2 * du * z)**2) / wavelength
    v_limit = 1.0 / math.sqrt(1 + (2 * dv * z)**2) / wavelength
    bandlimit = (np.abs(u) < u_limit) & (np.abs(v) < v_limit)
    
    uv_sq = u ** 2 + v ** 2
    not_evanescent = (1.0 / wavelength**2 > uv_sq)

    mask = not_evanescent & bandlimit
    
    g = np.zeros((2 * xsize, 2 * ysize), dtype = np.complex)
    g[mask] = np.exp(1.0j * np.sqrt(1.0 / wavelength**2 - uv_sq[mask]) * z)
    
    return np.fft.ifft2(g * np.fft.fft2(src_expanded))[(xsize//2):(3*xsize//2), (ysize//2):(3*ysize//2)]

# %%
wavelength = 632.8e-9
k = 2.0 * math.pi / wavelength

a = 1000.05624604543e-3
b = 10.6068254211646e-3

f1 = 0.0
f2 = f1 + 2.0 * math.hypot(a, b)

# parabola part
p = 0.0562460454334836e-3

# whole mirror
WD = 1902.50110774383e-3
ML = 200.0e-3

# 接合点を求める2次方程式
param1 = a**-2
param2 = -(f1 + f2) / a**2 + 4 * p / b**2
param3 = (f1 + f2)**2 / (4 * a**2) - 4 * p * (p + f2) / b**2 - 1.0
seam = (-param2 - math.sqrt(param2**2 - 4.0 * param1 * param3)) / (2.0 * param1)

# xy plane params
entrance_radius = math.sqrt(-4 * p * (f1 - WD - ML - p - f2))
seam_radius = math.sqrt(-4 * p * (seam - p - f2))
exit_radius = b * math.sqrt((f1 - WD - (f1 + f2) / 2)**2 / a**2 - 1.0)
ring_radius = seam_radius * WD / (f1 - seam)

ring_thickness = exit_radius - ring_radius

# equipment params
ccd_num = 4096

def print_param(x):
    print(x, ':', eval(x))

print_param('exit_radius')
print_param('ring_radius')
print_param('seam_radius')
print_param('entrance_radius')
print_param('ring_thickness')
print(30.0 - (exit_radius - ring_radius))
# Out:
# exit_radius : 0.028900860897701938
# ring_radius : 0.028537516616092457
# seam_radius : 0.030000000000022727
# entrance_radius : 0.030381921069158307
# ring_thickness : 0.00036334428160948035
# 29.99963665571839

# %%
# Transverse Translation

binning = 2
ccd_pitch = 9.0e-6 * binning
N = round(ccd_num / binning)
detector_length = ccd_pitch * N

# simulation params
CD = WD
exit_pixel_size = wavelength * CD / detector_length
exit_length = N * exit_pixel_size

print_param('CD')
print_param('exit_pixel_size')
print_param('exit_length')
# Out:
# CD : 1.90250110774383
# exit_pixel_size : 3.265795087294639e-05
# exit_length : 0.06688348338779421

# %%
pinhole_rev_radius = 57.26e-3 / 2
#pinhole_radius = 2.25e-3 / 2
pinhole_radius = 4.5e-3 / 2

step_deg = 0.004 * 337
step_rad = step_deg / 180 * math.pi
#scan_num = 268
scan_num = 134

pinhole_margin = 0.0
pinhole_thickness = 0.0

print_param('pinhole_rev_radius')
print_param('pinhole_radius')
# Out:
# pinhole_rev_radius : 0.02863
# pinhole_radius : 0.00225

# %%
def isInPinhole(x, y, theta):
    return np.hypot(x - pinhole_rev_radius * math.cos(theta), y - pinhole_rev_radius * math.sin(theta)) < pinhole_radius

def getPinholeMask(rot_theta):
    x = np.linspace(-0.5 * exit_length, 0.5 * exit_length, N)
    y = x.copy()
    x, y = np.meshgrid(x, y)

    hole0 = isInPinhole(x, y, rot_theta)
    hole1 = isInPinhole(x, y, rot_theta + 0.25 * math.pi)
    hole2 = isInPinhole(x, y, rot_theta + math.pi)

    return hole0 | hole1 | hole2

# %%
def showImg(np_array):
    plt.imshow(np_array, origin='lower')

# %%
plt.figure(figsize=(5, 5))
showImg(getPinholeMask(0.0))

# %%
x = np.linspace(-0.5 * exit_length, 0.5 * exit_length, N)
y = x.copy()
x, y = np.meshgrid(x, y)

r = np.hypot(x, y)
theta = np.arctan2(y, x)

ring = np.zeros((N, N), dtype=np.complex)
on_ring = (ring_radius <= r) & (r <= exit_radius)
ring[on_ring] = 1.0

fig = plt.figure(figsize=(8, 8))
plt.axis('off')
plt.subplots_adjust(left=0, right=1, bottom=0, top=1)
showImg(np.abs(ring))
fig.savefig('../resource/chap3/ring.png')

# %%
whole_focus = fraunhofer(ring, WD)

fig = plt.figure(figsize=(8, 8))
plt.axis('off')
plt.subplots_adjust(left=0, right=1, bottom=0, top=1)
showImg(np.abs(whole_focus))
fig.savefig('../../thesis/chap3/figure/full_field_focus.png')

# %%
x = np.linspace(-0.5 * exit_length, 0.5 * exit_length, N)
y = x.copy()
x, y = np.meshgrid(x, y)

hole = isInPinhole(x, y, 0.0)

fig = plt.figure(figsize=(8, 8))

showImg(hole)
plt.axis('off')
plt.subplots_adjust(left=0, right=1, bottom=0, top=1)
fig.savefig('../resource/chap3/single_pinhole.png')

single_pinhole_focus = fraunhofer(ring * hole, WD)
#single_pinhole_focus = angular(single_pinhole_focus, ccd_pitch, wavelength, 300e-3)

fig = plt.figure(figsize=(8, 8))
plt.axis('off')
plt.subplots_adjust(left=0, right=1, bottom=0, top=1)
showImg(np.abs(single_pinhole_focus))
fig.savefig('../../thesis/chap3/figure/single_pinhole_focus.png')

# %%
pinhole_out = ring * getPinholeMask(0.0)
pinhole_focus = fraunhofer(pinhole_out, CD)

fig = plt.figure(figsize=(8, 8))
plt.axis('off')
plt.subplots_adjust(left=0, right=1, bottom=0, top=1)
showImg(np.abs(pinhole_focus))
fig.savefig('../../thesis/chap3/figure/three_pinhole_focus.png')

# %%
whole_profile = np.abs(whole_focus[N//2, :])
whole_profile_max = np.max(whole_profile)
whole_profile /= whole_profile_max

fig = plt.figure(figsize=(20, 4))
x = np.linspace(-0.5 * detector_length, 0.5 * detector_length, N)
plt.plot(x, whole_profile)

# %%
single_pinhole_profile = np.abs(single_pinhole_focus[N//2, :])
single_pinhole_profile_max = np.max(single_pinhole_profile)
single_pinhole_profile /= single_pinhole_profile_max

fig = plt.figure(figsize=(20, 4))
x = np.linspace(-0.5 * detector_length, 0.5 * detector_length, N)
plt.plot(x, single_pinhole_profile)

# %%
pinhole_profile = np.abs(pinhole_focus[N//2, :])
pinhole_profile_max = np.max(pinhole_profile)
pinhole_profile /= pinhole_profile_max

fig = plt.figure(figsize=(20, 4))
x = np.linspace(-0.5 * detector_length, 0.5 * detector_length, N)
plt.plot(x, pinhole_profile)

#fig.savefig('artifacts/detector_profile.png')

# %%
fig = plt.figure(figsize=(20, 8))
#plt.plot(x, pinhole_profile, label='Three Pinhole Diffraction')
plt.plot(x, single_pinhole_profile, label='Single Pinhole Diffraction')
plt.plot(x, whole_profile, label='Full Field Diffraction')
#plt.plot(x, 0.01 * np.ones(x.shape[0]))

plt.legend()

fig.savefig('../../thesis/chap3/figure/pinhole_dynamic_range_superiority.png')

# %%
# 全面照明集光のダイナミックレンジに対応する有効領域を求める

x = np.linspace(-0.5 * exit_length, 0.5 * exit_length, N)

dynamic_range = [2**16, 2**15, 2**14, 2**13, 2**12, 2**11, 2**10, 2**9, 2**8, 2**7]
effective_range = np.array([ 2.0 * abs(x[np.where(whole_profile > 1.0 / dr)[0][0]]) for dr in dynamic_range])

plt.xscale('log')
plt.plot(np.array(dynamic_range), np.array(effective_range))

# %%
# 全面照明集光のダイナミックレンジに対応する有効領域を求める

x = np.linspace(-0.5 * exit_length, 0.5 * exit_length, N)

dynamic_range = [2**16, 2**15, 2**14, 2**13, 2**12, 2**11, 2**10, 2**9, 2**8, 2**7]
effective_range = np.array([ 2.0 * abs(x[np.where(pinhole_profile > 1.0 / dr)[0][0]]) for dr in dynamic_range])

plt.xscale('log')
plt.plot(np.array(dynamic_range), np.array(effective_range))

# %%
# ランダム初期化
x = cp.linspace(-0.5 * exit_length, 0.5 * exit_length, N)
y = x.copy()
x, y = cp.meshgrid(x, y)
r = cp.hypot(x, y)
theta = cp.arctan2(x, y) + math.pi

ring = cp.random.randn(N, N) * cp.exp(1.0j * cp.random.randn(N, N))
ring[(r < pinhole_rev_radius - pinhole_radius) | (pinhole_rev_radius + pinhole_radius < r)] = 0.0

plt.figure(figsize=(5, 5))
plt.title('init ring')
showImg(cp.abs(ring))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-197-4b703953848d> in <module>
#      11 plt.figure(figsize=(5, 5))
#      12 plt.title('init ring')
# ---> 13 showImg(cp.abs(ring))
#
# <ipython-input-177-0f319b2db59f> in showImg(np_array)
#       1 def showImg(np_array):
# ----> 2     plt.imshow(np_array, origin='lower')
#
# ~/.pyenv/versions/3.8.6/lib/python3.8/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
#    2722         filternorm=True, filterrad=4.0, resample=None, url=None,
#    2723         data=None, **kwargs):
# -> 2724     __ret = gca().imshow(
#    2725         X, cmap=cmap, norm=norm, aspect=aspect,
#    2726         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# ~/.pyenv/versions/3.8.6/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/.pyenv/versions/3.8.6/lib/python3.8/site-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, **kwargs)
#    5521                               resample=resample, **kwargs)
#    5522
# -> 5523         im.set_data(X)
#    5524         im.set_alpha(alpha)
#    5525         if im.get_clip_path() is None:
#
# ~/.pyenv/versions/3.8.6/lib/python3.8/site-packages/matplotlib/image.py in set_data(self, A)
#     696         if isinstance(A, PIL.Image.Image):
#     697             A = pil_to_array(A)  # Needed e.g. to apply png palette.
# --> 698         self._A = cbook.safe_masked_invalid(A, copy=True)
#     699
#     700         if (self._A.dtype != np.uint8 and
#
# ~/.pyenv/versions/3.8.6/lib/python3.8/site-packages/matplotlib/cbook/__init__.py in safe_masked_invalid(x, copy)
#     680
#     681 def safe_masked_invalid(x, copy=False):
# --> 682     x = np.array(x, subok=True, copy=copy)
#     683     if not x.dtype.isnative:
#     684         # If we have already made a copy, do the byteswap in place, else make a
#
# cupy/core/core.pyx in cupy.core.core.ndarray.__array__()
#
# TypeError: Implicit conversion to a NumPy array is not allowed. Please use `.get()` to construct a NumPy array explicitly.
